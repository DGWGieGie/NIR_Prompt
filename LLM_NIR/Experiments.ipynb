# %%
import candidateSet

# %% [markdown]
# # UserFilter

# %%
NIR1 = candidateSet.uiMatrix("ml-100k_NIR1.json", USER=1, RATING=0)
# NIR0 = candidateSet.uiMatrix("ml-100k_NIR0.json", USER=1)

# %%
simi = ["cosine", "euclidean", "jaccard" , "manhattan"]

# %%
similaritys = candidateSet.Similarity(NIR1.uiMatrix, ["cosine", "jaccard" , "manhattan"])
# Out:
# /Users/DGW/miniforge3/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1975: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
results_data_15 = []
num_u = 13
total_i = 20
count = 0
total = 0
for i in range(len(NIR1.uiMatrix)):
    elem = NIR1.uiData[i]
    
    candidate_items = NIR1.getCandidate(i, similaritys.getSimilaritys(i), 13, 20, 0)

    if elem[-1] in candidate_items:
        count += 1
    total +=1
print (f'count/total:{count}/{total}={count*1.0/total}')
print ('-----------------\n')
# Out:
# count/total:170/943=0.18027571580063625
# -----------------

# %% [markdown]
# # ItemFilter

# %%
NIR1 = candidateSet.uiMatrix("ml-100k_NIR1.json", USER=0, RATING=1)
# NIR0 = candidateSet.uiMatrix("ml-100k_NIR0.json", USER=1)

# %%
simi = ["cosine", "euclidean", "jaccard" , "manhattan"]

# %%
similaritys = candidateSet.Similarity(NIR1.uiMatrix, ["cosine", "euclidean", "jaccard" , "manhattan"])
# Out:
# /Users/DGW/miniforge3/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1975: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
results_data_15 = []
num_u = 13
total_i = 20
count = 0
total = 0
for i in range(len(NIR1.uiData)):
    elem = NIR1.uiData[i]
    
    candidate_items = NIR1.getCandidate(i, similaritys.getSimilaritysAll(), 13, 20, 0)

    if elem[-1] in candidate_items:
        count += 1
    total +=1
print (f'count/total:{count}/{total}={count*1.0/total}')
print ('-----------------\n')
# Out:
# count/total:105/943=0.11134676564156946
# -----------------

# %% [markdown]
# ## UserFilter
# ### RATING = 0
#
# + *baseline: count/total:170/943=0.180* & count/total:74/170=0.435(NIR_Method)
#
#
# + Cosine: count/total:172/943=0.182
# + Euclidean: count/total:170/943=0.180
# + **Jaccard: count/total:175/943=0.186** & **count/total:97/175=0.554(NIR_Method)** & count/total:89/175=0.509  & count/total:92/175=0.526(exchange) & count/total:89/175=0.509(exchange+modify)
# + Manhattan: count/total:170/943=0.180
#
#
# + Cosine+Euclidean: count/total:171/943=0.181
# + **Cosine+Jaccard: count/total:174/943=0.185** &
# + Cosine+Manhattan: count/total:169/943=0.179
# + Euclidean+Jaccard: count/total:173/943=0.183
# + Euclidean+Manhattan: count/total:170/943=0.180
# + Jaccard+Manhattan: count/total:172/943=0.182
#
#
# + Cosine+Euclidean+Jaccard: count/total:170/943=0.180
# + Cosine+Euclidean+Manhattan: count/total:177/943=0.188
# + Cosine+Jaccard+Manhattan: count/total:170/943=0.180
# + **Euclidean+Jaccard+Manhattan: count/total:178/943=0.189** & count/total:89/175=0.508 &
#
#
# + Cosine+Euclidean+Jaccard+Manhattan: count/total:176/943=0.187 & count/total:92/176=0.523(NIR_Method)
#
# ### RATING = 1
# + Cosine: count/total:163/943=0.172
# + Euclidean: count/total:147/943=0.156
# + **Jaccard: count/total:175/943=0.186** & count/total:93/175=0.531
# + Manhattan: count/total:146/943=0.155
#
#
# + Cosine+Euclidean: count/total:159/943=0.169
# + **Cosine+Jaccard: count/total:169/943=0.179** & count/total:87/169=0.514
# + Cosine+Manhattan: count/total:159/943=0.169
# + Euclidean+Jaccard: count/total:163/943=0.173
# + Euclidean+Manhattan: count/total:153/943=0.162
# + Jaccard+Manhattan: count/total:167/943=0.177
#
#
# + Cosine+Euclidean+Jaccard: count/total:169/943=0.180
# + Cosine+Euclidean+Manhattan: count/total:160/943=0.170
# + **Cosine+Jaccard+Manhattan: count/total:170/943=0.180** count/total:87/170=0.511
# + Euclidean+Jaccard+Manhattan: count/total:162/943=0.172
#
#
# + Cosine+Euclidean+Jaccard+Manhattan: count/total:165/943=0.175 & count/total:90/165=0.545
#
#
# ## ItemFilter
# ### RATING = 0
#
# + **Cosine: count/total:166/943=0.176**
# + Euclidean: count/total:24/943=0.025
# + Jaccard: count/total:167/943=0.177
# + Manhattan: count/total:24/943=0.025
#
#
# + Cosine+Euclidean: count/total:109/943=0.116
# + **Cosine+Jaccard: count/total:169/943=0.179**
# + Cosine+Manhattan: count/total:109/943=0.116
# + Euclidean+Jaccard: count/total:111/943=0.117
# + Euclidean+Manhattan: count/total:24/943=0.025
# + Jaccard+Manhattan: count/total:110/943=0.117
#
#
# + **Cosine+Euclidean+Jaccard: count/total:147/943=0.156**
# + Cosine+Euclidean+Manhattan: count/total:69/943=0.073
# + Cosine+Jaccard+Manhattan: count/total:146/943=0.155
# + Euclidean+Jaccard+Manhattan: count/total:67/943=0.071
#
#
# + Cosine+Euclidean+Jaccard+Manhattan: count/total:109/943=0.116
#
# ### RATING = 1
# + **Cosine: count/total:171/943=0.181**
# + Euclidean: count/total:32/943=0.034
# + Jaccard: count/total:167/943=0.177
# + Manhattan: count/total:10/943=0.011
#
#
# + Cosine+Euclidean: count/total:113/943=0.120
# + **Cosine+Jaccard: count/total:176/943=0.187**
# + Cosine+Manhattan: count/total:96/943=0.102
# + Euclidean+Jaccard: count/total:115/943=0.122
# + Euclidean+Manhattan: count/total:15/943=0.016
# + Jaccard+Manhattan: count/total:96/943=0.102
#
#
# + **Cosine+Euclidean+Jaccard: count/total:156/943=0.165**
# + Cosine+Euclidean+Manhattan: count/total:63/943=0.067
# + Cosine+Jaccard+Manhattan： count/total:138/943=0.146
# + Euclidean+Jaccard+Manhattan: count/total:67/943=0.071
#
#
# + Cosine+Euclidean+Jaccard+Manhattan: count/total:105/943=0.111

# %% [markdown]
# # Baseline Test

# %%
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

# %%
# !python3 main.py --RATING 0  --similarity "jaccard" --length_limit 15 --API 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 --saveFile "jaccard_fewShot_exPrompt.json"
# Out:
# /Users/DGW/miniforge3/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1975: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# count/total:167/943=0.17709437963944857
# -----------------
#
# Using GPT
# GT:Clear and Present Danger
# Refine Summary:Based on the movies you have watched, it seems that you enjoy action, sci-fi, and adventure genres. You also seem to prefer movies with strong characters and engaging storylines. Additionally, you have shown a preference for movies with high production value and popular franchises such as Star Trek.
# predictions:Sure, here are 10 movies from the Candidate Set that are similar to the movies you have watched:
#
# 1. Die Hard: With a Vengeance - Die Hard 2
# 2. Jurassic Park - Independence Day
# 3. The Terminator - Terminator 2: Judgment Day
# 4. Full Metal Jacket - Platoon
# 5. Star Trek: First Contact - Star Trek: Generations
# ...

# %%
# !python3 main.py --RATING 0 --filename "ml_100k.json"  --similarity "jaccard" --API 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 --saveFile "jaccard_fewShot_non.json"
# Out:
# /Users/DGW/miniforge3/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1975: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# count/total:169/943=0.1792152704135737
# -----------------
#
# Using GPT
# GT:Under Siege 2: Dark Territory
# Refine Summary:Based on the movies you have watched, it seems that you enjoy action movies with a lot of suspense and thrill. You may also prefer movies with a strong lead character and a fast-paced plot.
# predictions:Sure, here are 10 movies from the Candidate Set that are similar to the movies you have watched:
#
# 1. True Lies - GoldenEye
# 2. Speed - Terminal Velocity
# 3. Last Man Standing - Young Guns
# 4. Demolition Man - Waterworld
# 5. Eraser - Clear and Present Danger
# 6. Last Action Hero - The Shadow
# 7. Cliffhanger - In the Line of Fire
# 8. Star Trek: The Motion Picture - Star Trek IV: The Voyage Home
# 9. Die Hard 2 - Under Siege 2: Dark Territory
# ...
